# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-4.8.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from datasets) (21.0.0)
# Collecting dill<0.4.2,>=0.3.0 (from datasets)
#   Downloading dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: httpx<1.0.0 in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.28.1)
# Collecting tqdm>=4.66.3 (from datasets)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.6.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.20 (from datasets)
#   Downloading multiprocess-0.70.19-py312-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2024.2.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from datasets) (6.0.1)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets)
#   Downloading aiohttp-3.13.3-cp312-cp312-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: anyio in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0->datasets) (4.9.0)
# Requirement already satisfied: certifi in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0->datasets) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0->datasets) (3.6)
# Requirement already satisfied: h11>=0.16 in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.13.0)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (25.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets)
#   Downloading frozenlist-1.8.0-cp312-cp312-win_amd64.whl.metadata (21 kB)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.4.4)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets)
#   Downloading propcache-0.4.1-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets)
#   Downloading yarl-1.23.0-cp312-cp312-win_amd64.whl.metadata (82 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.32.2->datasets) (1.26.15)
# Requirement already satisfied: colorama in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kaile\appdata\roaming\python\python312\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\kaile\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-4.8.2-py3-none-any.whl (526 kB)
#    ---------------------------------------- 0.0/526.6 kB ? eta -:--:--
#    ---------------------------------------- 526.6/526.6 kB 8.5 MB/s  0:00:00
# Downloading dill-0.4.1-py3-none-any.whl (120 kB)
# Downloading multiprocess-0.70.19-py312-none-any.whl (150 kB)
# Downloading aiohttp-3.13.3-cp312-cp312-win_amd64.whl (455 kB)
# Downloading yarl-1.23.0-cp312-cp312-win_amd64.whl (87 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp312-cp312-win_amd64.whl (44 kB)
# Downloading propcache-0.4.1-cp312-cp312-win_amd64.whl (41 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading xxhash-3.6.0-cp312-cp312-win_amd64.whl (31 kB)
# Installing collected packages: xxhash, tqdm, propcache, frozenlist, dill, aiohappyeyeballs, yarl, multiprocess, aiosignal, aiohttp, datasets
#
#   Attempting uninstall: tqdm
#
#     Found existing installation: tqdm 4.66.2
#
#     Uninstalling tqdm-4.66.2:
#
#    --- ------------------------------------  1/11 [tqdm]
#       Successfully uninstalled tqdm-4.66.2
#    --- ------------------------------------  1/11 [tqdm]
#    --- ------------------------------------  1/11 [tqdm]
#    --- ------------------------------------  1/11 [tqdm]
#    --- ------------------------------------  1/11 [tqdm]
#    --- ------------------------------------  1/11 [tqdm]
#    --- ------------------------------------  1/11 [tqdm]
#    --- ------------------------------------  1/11 [tqdm]
#    --- ------------------------------------  1/11 [tqdm]
#    ------- --------------------------------  2/11 [propcache]
#    -------------- -------------------------  4/11 [dill]
#    -------------- -------------------------  4/11 [dill]
#    -------------- -------------------------  4/11 [dill]
#    -------------- -------------------------  4/11 [dill]
#    -------------- -------------------------  4/11 [dill]
#    -------------- -------------------------  4/11 [dill]
#    -------------- -------------------------  4/11 [dill]
#    -------------- -------------------------  4/11 [dill]
#    -------------- -------------------------  4/11 [dill]
#    ------------------ ---------------------  5/11 [aiohappyeyeballs]
#    --------------------- ------------------  6/11 [yarl]
#    --------------------- ------------------  6/11 [yarl]
#    ------------------------- --------------  7/11 [multiprocess]
#    ------------------------- --------------  7/11 [multiprocess]
#    ------------------------- --------------  7/11 [multiprocess]
#    ------------------------- --------------  7/11 [multiprocess]
#    ------------------------- --------------  7/11 [multiprocess]
#    ------------------------- --------------  7/11 [multiprocess]
#    ------------------------- --------------  7/11 [multiprocess]
#    ------------------------- --------------  7/11 [multiprocess]
#    ------------------------- --------------  7/11 [multiprocess]
#    ----------------------------- ----------  8/11 [aiosignal]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ------------------------------------ --- 10/11 [datasets]
#    ---------------------------------------- 11/11 [datasets]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 datasets-4.8.2 dill-0.4.1 frozenlist-1.8.0 multiprocess-0.70.19 propcache-0.4.1 tqdm-4.67.3 xxhash-3.6.0 yarl-1.23.0
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("UniversalCEFR/readme_en")
# Out:
# README.md:   0%|          | 0.00/810 [00:00<?, ?B/s]
# c:\Users\kaile\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:144: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\kaile\.cache\huggingface\hub\datasets--UniversalCEFR--readme_en. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# readme_en.json: 0.00B [00:00, ?B/s]
# Generating train split:   0%|          | 0/2822 [00:00<?, ? examples/s]

# %%
print(ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'lang', 'source_name', 'format', 'category', 'cefr_level', 'license', 'text'],
#         num_rows: 2822
#     })
# })

# %%
# Convert a specific split to Pandas
df = ds['train'].to_pandas()

# View the top 5 rows
df.head()
# Out:
#   title lang source_name          format   category cefr_level  \
# 0    na   en      readme  sentence-level  reference         C1
# 1    na   en      readme  sentence-level  reference         C1
# 2    na   en      readme  sentence-level  reference         B2
# 3    na   en      readme  sentence-level  reference         B1
# 4    na   en      readme  sentence-level  reference         B1
#
#            license                                               text
# 0  CC BY SA NC 4.0  The price elasticity of demand depends on the ...
# 1  CC BY SA NC 4.0  To  find the derivative needed to calculate th...
# 2  CC BY SA NC 4.0  A cartel is a group of firms that have an expl...
# 3  CC BY SA NC 4.0  If both firms select the same category,  both ...
# 4  CC BY SA NC 4.0  The market  mechanism is a useful and powerful...

# %%
import pandas as pd

df.to_excel("english_data.xlsx", index=False)

# %% [markdown]
# # Loading the Vocab Words

# %%
vocab = pd.read_csv("vocab.csv")

# %%
print(vocab.head(10))
# Out:
#    Rank  Word  Frequency count Stem  Stem valid probability
# 0     1   the      93354873907  NaN                     NaN
# 1     2    of      56714371798  NaN                     NaN
# 2     3   and      41046370216  NaN                     NaN
# 3     4    to      34424370945  NaN                     NaN
# 4     5    in      30289691557  NaN                     NaN
# 5     6     a      26251832128  NaN                     NaN
# 6     7    is      14623642934  NaN                     NaN
# 7     8  that      13817006267  NaN                     NaN
# 8     9   for      13530602566  NaN                     NaN
# 9    10    as       9617641572  NaN                     NaN

# %%
print(vocab.info())
print(vocab.describe())
print(vocab.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172782 entries, 0 to 172781
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Rank                    172782 non-null  int64
#  1   Word                    172780 non-null  object
#  2   Frequency count         172782 non-null  int64
#  3   Stem                    71429 non-null   object
#  4   Stem valid probability  71446 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 6.6+ MB
# None
#                 Rank  Frequency count  Stem valid probability
# count  172782.000000     1.727820e+05            71446.000000
# mean    86391.500000     7.789179e+06                0.791486
# std     49878.011443     3.272305e+08                0.277786
# min         1.000000     1.000000e+04                0.001000
# 25%     43196.250000     3.563000e+04                0.689100
# 50%     86391.500000     1.395855e+05                0.929700
# 75%    129586.750000     7.435550e+05                0.992000
# max    172782.000000     9.335487e+10                0.999000
# Rank                           0
# Word                           2
# Frequency count                0
# Stem                      101353
# Stem valid probability    101336
# dtype: int64
